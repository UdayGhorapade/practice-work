# %% [markdown]
# <a href="https://colab.research.google.com/github/UdayGhorapade/practice-work/blob/main/COmpactibility%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
df=pd.read_excel('/content/31-7-21.xlsx')

# %%
df.head()
# Out:
#    Set_H2O_cor  Meas_H2O  Meas_Temp  Weight  Lit_Main  Set_Comp  Meas_Comp1
# 0         3.00      2.28       38.2    1800      15.1        45        45.2
# 1         3.03      2.28       37.8    1800      14.6        45        43.6
# 2         3.06      2.26       38.4    1800      15.5        45        41.9
# 3         3.03      2.29       38.2    1800      15.5        45        47.1
# 4         3.00      2.30       37.9    1800      14.8        45        46.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Set_H2O_cor  201 non-null    float64
#  1   Meas_H2O     201 non-null    float64
#  2   Meas_Temp    201 non-null    float64
#  3   Weight       201 non-null    int64
#  4   Lit_Main     201 non-null    float64
#  5   Set_Comp     201 non-null    int64
#  6   Meas_Comp1   201 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 11.1 KB

# %%
df.isnull()
# Out:
#      Set_H2O_cor  Meas_H2O  Meas_Temp  Weight  Lit_Main  Set_Comp  Meas_Comp1
# 0          False     False      False   False     False     False       False
# 1          False     False      False   False     False     False       False
# 2          False     False      False   False     False     False       False
# 3          False     False      False   False     False     False       False
# 4          False     False      False   False     False     False       False
# ..           ...       ...        ...     ...       ...       ...         ...
# 196        False     False      False   False     False     False       False
# 197        False     False      False   False     False     False       False
# 198        False     False      False   False     False     False       False
# 199        False     False      False   False     False     False       False
# 200        False     False      False   False     False     False       False
#
# [201 rows x 7 columns]

# %%
x=df.drop(['Meas_Comp1'],axis=1)
y=df['Meas_Comp1'].values.reshape(-1,1)

# %%
x
# Out:
#      Set_H2O_cor  Meas_H2O  Meas_Temp  Weight  Lit_Main  Set_Comp
# 0           3.00      2.28       38.2    1800      15.1        45
# 1           3.03      2.28       37.8    1800      14.6        45
# 2           3.06      2.26       38.4    1800      15.5        45
# 3           3.03      2.29       38.2    1800      15.5        45
# 4           3.00      2.30       37.9    1800      14.8        45
# ..           ...       ...        ...     ...       ...       ...
# 196         3.15      2.13       39.9    1800      19.8        44
# 197         3.18      2.13       39.8    1800      20.3        44
# 198         3.21      2.12       40.0    1800      21.0        44
# 199         3.24      2.10       40.1    1800      21.9        44
# 200         3.21      2.07       40.2    1800      23.0        44
#
# [201 rows x 6 columns]

# %%
y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:413: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression
mlp_reg=LinearRegression()
mlp_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y_pred=mlp_reg.predict(x_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
print('enter the value of:')
Set_H2O_cor=float(input('Set_H2O_cor:'))
Meas_H2O=float(input('Meas_H2O:'))
Meas_Temp=float(input('Meas_Temp:'))
Weight=int(input('Weight:'))
Lit_Main=float(input('Lit_Main:'))
Set_Comp=int(input('Set_Comp:'))


output=mlp_reg.predict([[[[[[Set_H2O_cor,Meas_H2O,Meas_Temp,Weight,Lit_Main,Set_Comp]]]]]])
print('output', output)
# Out:
# enter the value of:
# Set_H2O_cor:3.5
# Meas_H2O:2.5
# Meas_Temp:45
# Weight:1800
# Lit_Main:15
# Set_Comp:45
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-91196b212af4> in <module>
#       8
#       9
# ---> 10 output=mlp_reg.predict([[[[[[Set_H2O_cor,Meas_H2O,Meas_Temp,Weight,Lit_Main,Set_Comp]]]]]])
#      11 print('output', output)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-816f291db71f> in <module>
# ----> 1 output=mlp_reg.predict([[[[[[Set_H2O_cor,Meas_H2O,Meas_Temp,Weight,Lit_Main,Set_Comp]]]]]])
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     339
#
# ...
